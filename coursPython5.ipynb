# %% [markdown]
# ## Projet Analyse des Données Bancaires
#
# ### Contexte
#
# Vous êtes data scientist/data analyst dans une banque et votre entreprise souhaite analyser l'efficacité des campagnes de marketing direct basées sur les appels téléphoniques.
#
# L'objectif est de déterminer si ces campagnes influencent positivement la souscription des clients à des dépôts à terme.
#
# Pour cela, vous disposez de quatre ensembles de données détaillant les interactions avec les clients sur une période allant de mai 2008 à novembre 2010.
#
# ### Objectif
#
# Votre mission consiste à effectuer une analyse exploratoire des données pour identifier les tendances, les comportements des clients, et d'autres insights pertinents qui peuvent aider la banque à optimiser ses futures campagnes de marketing.

# %% [markdown]
# ## Jeu de Données
#
# Vous disposez du jeu de données donnee_marketing_banque.csv, qui comprend 41 188 exemples avec 20 variables, couvrant la période de mai 2008 à novembre 2010. Ces données incluent des informations sur les appels effectués, les caractéristiques des clients, et la réponse finale du client (souscription ou non à un dépôt à terme).
#
# Le jeu de données peut être téléchargé à partir du UCI Machine Learning Repository: https://archive.ics.uci.edu/dataset/222/bank+marketing

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # importer un ficher csv
#
# Documentation de pd.read_csv: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
df = pd.read_csv("donnees_marketing_banque.csv", sep = ";")
df
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# # importer un ficher excel

# %%
ex = pd.read_excel("donnees_marketing_banque.xlsx")
ex
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
df.head()
# Out:
#     id  age           job  marital  education default  balance housing loan  \
# 0  id1   58    management  married   tertiary      no   2143.0     yes   no
# 1  id2   44    technician   single  secondary      no     29.0     yes   no
# 2  id3   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3  id4   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4  id5   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.head(10)
# Out:
#      id  age           job   marital  education default  balance housing loan  \
# 0   id1   58    management   married   tertiary      no   2143.0     yes   no
# 1   id2   44    technician    single  secondary      no     29.0     yes   no
# 2   id3   33  entrepreneur   married  secondary      no      2.0     yes  yes
# 3   id4   47   blue-collar   married    unknown      no   1506.0     yes   no
# 4   id5   33       unknown    single    unknown      no      1.0      no   no
# 5   id6   35    management   married   tertiary      no    231.0     yes   no
# 6   id7   28    management    single   tertiary      no    447.0     yes  yes
# 7   id8   42  entrepreneur  divorced   tertiary     yes      2.0     yes   no
# 8   id9   58       retired   married    primary      no    121.0     yes   no
# 9  id10   43    technician    single  secondary      no      NaN     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df.tail(5)
# Out:
#             id  age           job   marital  education default  balance  \
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45206      no   no   cellular   17   nov       977         3     -1         0
# 45207      no   no   cellular   17   nov       456         2     -1         0
# 45208      no   no   cellular   17   nov      1127         5    184         3
# 45209      no   no  telephone   17   nov       508         4     -1         0
# 45210      no   no   cellular   17   nov       361         2    188        11
#
#       poutcome    y
# 45206  unknown  yes
# 45207  unknown  yes
# ...

# %%
df.tail(10)
# Out:
#             id  age           job   marital  education default  balance  \
# 45201  id45202   53    management   married   tertiary      no    583.0
# 45202  id45203   34        admin.    single  secondary      no    557.0
# 45203  id45204   23       student    single   tertiary      no    113.0
# 45204  id45205   73       retired   married  secondary      no   2850.0
# 45205  id45206   25    technician    single  secondary      no    505.0
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45201      no   no   cellular   17   nov       226         1    184         4
# ...

# %% [markdown]
# # Quel sont les variables de l'analyse ?

# %%
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id            object
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %% [markdown]
# # combien de client et combien de variables ?

# %%
df.shape
# Out:
# (45211, 18)

# %% [markdown]
# # Description rapide de la base

# %%
# pour le solde du compte on peux voir des données manquantes (balance)
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45206.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.403707     15.806419    258.163080      2.763841
# std       10.623372    3044.906741      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.describe(include = "all")
# Out:
#            id           age          job  marital  education default  \
# count   45211  45211.000000        45211    45211      45211   45211
# unique  45211           NaN           12        3          4       2
# top       id1           NaN  blue-collar  married  secondary      no
# freq        1           NaN         9732    27214      23202   44396
# mean      NaN     40.931477          NaN      NaN        NaN     NaN
# std       NaN     10.623372          NaN      NaN        NaN     NaN
# min       NaN     10.000000          NaN      NaN        NaN     NaN
# 25%       NaN     33.000000          NaN      NaN        NaN     NaN
# 50%       NaN     39.000000          NaN      NaN        NaN     NaN
# 75%       NaN     48.000000          NaN      NaN        NaN     NaN
# max       NaN     95.000000          NaN      NaN        NaN     NaN
#
#               balance housing   loan   contact           day  month  \
# count    45206.000000   45211  45211     45211  45211.000000  45211
# ...

# %%
df["education"].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
df["education"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# # gestion des valeurs manquantes

# %%
df.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      5
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.isna().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      5
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# supprimer les lignes manquantes
df_delete_ligne = df.dropna(axis= 0)
df_delete_ligne.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45206.000000   45206.000000  45206.000000  45206.000000  45206.000000
# mean      40.930828    1362.403707     15.807614    258.161616      2.764036
# std       10.623495    3044.906741      8.322160    257.539139      3.098137
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45206.000000  45206.000000
# mean      40.202385      0.580388
# std      100.133346      2.303560
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# supprimer les colonnes manquantes
df_delete_colonne = df.dropna(axis= 1)
df_delete_colonne.describe()
# Out:
#                 age           day      duration      campaign         pdays  \
# count  45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477     15.806419    258.163080      2.763841     40.197828
# std       10.623372      8.322476    257.527812      3.098021    100.128746
# min       10.000000      1.000000      0.000000      1.000000     -1.000000
# 25%       33.000000      8.000000    103.000000      1.000000     -1.000000
# 50%       39.000000     16.000000    180.000000      2.000000     -1.000000
# 75%       48.000000     21.000000    319.000000      3.000000     -1.000000
# max       95.000000     31.000000   4918.000000     63.000000    871.000000
#
#            previous
# count  45211.000000
# mean       0.580323
# std        2.303441
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      275.000000

# %%
df_remplace = df.fillna(0)
df_remplace.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.253036     15.806419    258.163080      2.763841
# std       10.623372    3044.772068      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
moyenne = df["balance"].mean()
df_remplace_moyenne = df.fillna(moyenne)
df_remplace_moyenne.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.403707     15.806419    258.163080      2.763841
# std       10.623372    3044.738361      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     449.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# # suppresion des colonnes inultiles

# %%
df_supp = df.drop(["month"], axis = 1)
df_supp
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day  duration  campaign  pdays  previous  \
# ...

# %%
df_supp2 = df.drop(["month", "day"], axis = 1)
df_supp2
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  duration  campaign  pdays  previous poutcome  \
# ...

# %%
# sélectionner une colonnes spécifiques
age = df["age"]
age
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %%
age.describe()
# Out:
# count    45211.000000
# mean        40.931477
# std         10.623372
# min         10.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
df.age
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df_select = df[["age", "loan", "education"]]
df_select
# Out:
#        age loan  education
# 0       58   no   tertiary
# 1       44   no  secondary
# 2       33  yes  secondary
# 3       47   no    unknown
# 4       33   no    unknown
# ...    ...  ...        ...
# 45206   51   no   tertiary
# 45207   71   no    primary
# 45208   72   no  secondary
# 45209   57   no  secondary
# 45210   37   no  secondary
#
# [45211 rows x 3 columns]

# %%
# selection avec .loc et récupération de toutes les lignes

liste_colomuns = ["age", "loan", "education"]
df_select2 = df.loc[0:11,liste_colomuns]
df_select2
# Out:
#     age loan  education
# 0    58   no   tertiary
# 1    44   no  secondary
# 2    33  yes  secondary
# 3    47   no    unknown
# 4    33   no    unknown
# 5    35   no   tertiary
# 6    28  yes   tertiary
# 7    42   no   tertiary
# 8    58   no    primary
# 9    43   no  secondary
# 10   41   no  secondary
# 11   29   no  secondary

# %%
# différence entre .loc et .iloc avec .iloc on va selectionner uniquement les index
df
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
df_iloc = df.iloc[:, [1,2,3]]
df_iloc
# Out:
#        age           job   marital
# 0       58    management   married
# 1       44    technician    single
# 2       33  entrepreneur   married
# 3       47   blue-collar   married
# 4       33       unknown    single
# ...    ...           ...       ...
# 45206   51    technician   married
# 45207   71       retired  divorced
# 45208   72       retired   married
# 45209   57   blue-collar   married
# 45210   37  entrepreneur   married
#
# [45211 rows x 3 columns]

# %%
# si on veux les 100 premières lignes
df_iloc = df.iloc[:100, [1,2,3]]
df_iloc
# Out:
#     age           job  marital
# 0    58    management  married
# 1    44    technician   single
# 2    33  entrepreneur  married
# 3    47   blue-collar  married
# 4    33       unknown   single
# ..  ...           ...      ...
# 95   36    management  married
# 96   55   blue-collar  married
# 97   60       retired  married
# 98   39    technician  married
# 99   46    management  married
#
# [100 rows x 3 columns]

# %% [markdown]
# # Sélectionner un périmètre d'analyse

# %%
# Comment selectionner toutes les personnes qui ont plus de 18 ans
df_majeur = df[df["age"] >= 18]
df_majeur.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45203.000000   45198.000000  45203.000000  45203.000000  45203.000000
# mean      40.936133    1362.631997     15.808331    258.168816      2.764153
# std       10.618494    3045.126997      8.321971    257.548471      3.098206
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     449.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45203.000000  45203.000000
# mean      40.205119      0.580426
# std      100.136106      2.303632
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# et qui sont en secondary
df_majeur = df[(df["age"] >= 18) & (df["education"] == "secondary")]
df_majeur.describe(include = "all")
# Out:
#            id           age          job  marital  education default  \
# count   23199  23199.000000        23199    23199      23199   23199
# unique  23199           NaN           12        3          1       2
# top       id2           NaN  blue-collar  married  secondary      no
# freq        1           NaN         5371    13769      23199   22741
# mean      NaN     39.964352          NaN      NaN        NaN     NaN
# std       NaN     10.159050          NaN      NaN        NaN     NaN
# min       NaN     18.000000          NaN      NaN        NaN     NaN
# 25%       NaN     32.000000          NaN      NaN        NaN     NaN
# 50%       NaN     38.000000          NaN      NaN        NaN     NaN
# 75%       NaN     47.000000          NaN      NaN        NaN     NaN
# max       NaN     95.000000          NaN      NaN        NaN     NaN
#
#              balance housing   loan   contact           day  month  \
# count   23197.000000   23199  23199     23199  23199.000000  23199
# ...

# %%
# avec .loc sa change rien 

df_majeur_loc = df.loc[(df["age"] >= 18) & (df["education"] == "secondary")]
df_majeur_loc.describe(include = "all")
# Out:
#            id           age          job  marital  education default  \
# count   23199  23199.000000        23199    23199      23199   23199
# unique  23199           NaN           12        3          1       2
# top       id2           NaN  blue-collar  married  secondary      no
# freq        1           NaN         5371    13769      23199   22741
# mean      NaN     39.964352          NaN      NaN        NaN     NaN
# std       NaN     10.159050          NaN      NaN        NaN     NaN
# min       NaN     18.000000          NaN      NaN        NaN     NaN
# 25%       NaN     32.000000          NaN      NaN        NaN     NaN
# 50%       NaN     38.000000          NaN      NaN        NaN     NaN
# 75%       NaN     47.000000          NaN      NaN        NaN     NaN
# max       NaN     95.000000          NaN      NaN        NaN     NaN
#
#              balance housing   loan   contact           day  month  \
# count   23197.000000   23199  23199     23199  23199.000000  23199
# ...

# %%
# df_majeur_iloc = df[(df.iloc[:100, [1]] >= 18 & (df.iloc[:100, 4] == "secondary"))]
# df_majeur_iloc
df_majeur_iloc = df.iloc[3:100, 5:10]
df_majeur_iloc
# Out:
#    default  balance housing loan  contact
# 3       no   1506.0     yes   no  unknown
# 4       no      1.0      no   no  unknown
# 5       no    231.0     yes   no  unknown
# 6       no    447.0     yes  yes  unknown
# 7      yes      2.0     yes   no  unknown
# ..     ...      ...     ...  ...      ...
# 95      no    101.0     yes  yes  unknown
# 96      no    383.0      no   no  unknown
# 97      no     81.0     yes   no  unknown
# 98      no      0.0     yes   no  unknown
# 99      no    229.0     yes   no  unknown
#
# [97 rows x 5 columns]

# %%
df_select = df.loc[df["age"] >= 18, ["age","job","balance"]]
df_select
# Out:
#        age           job  balance
# 0       58    management   2143.0
# 1       44    technician     29.0
# 2       33  entrepreneur      2.0
# 3       47   blue-collar   1506.0
# 4       33       unknown      1.0
# ...    ...           ...      ...
# 45206   51    technician    825.0
# 45207   71       retired   1729.0
# 45208   72       retired   5715.0
# 45209   57   blue-collar    668.0
# 45210   37  entrepreneur   2971.0
#
# [45203 rows x 3 columns]

# %%
df_select.describe(include = "all")
# Out:
#                  age          job        balance
# count   45203.000000        45203   45198.000000
# unique           NaN           12            NaN
# top              NaN  blue-collar            NaN
# freq             NaN         9732            NaN
# mean       40.936133          NaN    1362.631997
# std        10.618494          NaN    3045.126997
# min        18.000000          NaN   -8019.000000
# 25%        33.000000          NaN      72.000000
# 50%        39.000000          NaN     449.000000
# 75%        48.000000          NaN    1428.000000
# max        95.000000          NaN  102127.000000

# %%
# choisir les 10 premiers lignes
df_select = df.loc[:10, ["age","job","balance"]]
df_select
# Out:
#     age           job  balance
# 0    58    management   2143.0
# 1    44    technician     29.0
# 2    33  entrepreneur      2.0
# 3    47   blue-collar   1506.0
# 4    33       unknown      1.0
# 5    35    management    231.0
# 6    28    management    447.0
# 7    42  entrepreneur      2.0
# 8    58       retired    121.0
# 9    43    technician      NaN
# 10   41        admin.    270.0

# %% [markdown]
# # comment créer un colonne entre 18 et 25 et de 25 à 50 (update)

# %%
import numpy as np
df["tranche_age"] = np.nan

# %%
df["tranche_age"][df["age"] <= 18] = "<18"
# Out:
# C:\Users\Malik\AppData\Local\Temp\ipykernel_8584\119317111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tranche_age"][df["age"] <= 18] = "<18"

# %%
df["tranche_age"].describe
# Out:
# <bound method NDFrame.describe of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 45206    NaN
# 45207    NaN
# 45208    NaN
# 45209    NaN
# 45210    NaN
# Name: tranche_age, Length: 45211, dtype: object>

# %%
df["tranche_age"].unique()
# Out:
# array([nan, '<18'], dtype=object)

# %%
df["tranche_age"][df["age"] < 18] = "<18"
df["tranche_age"][(df["age"] >= 18) & (df["age"] < 25)] = "18-25"
df["tranche_age"][(df["age"] >= 25) & (df["age"] < 50)] = "25-50"
df["tranche_age"][(df["age"] >= 50)] = ">=50"

# %%
df["tranche_age"].unique()
# Out:
# array(['>=50', '25-50', '<18', '18-25'], dtype=object)

# %%
df.dtypes
# Out:
# id              object
# age              int64
# job             object
# marital         object
# education       object
# default         object
# balance        float64
# housing         object
# loan            object
# contact         object
# day              int64
# month           object
# duration         int64
# campaign         int64
# pdays            int64
# previous         int64
# poutcome        object
# y               object
# tranche_age     object
# dtype: object

# %%
df["tranche_age"].value_counts()
# Out:
# 25-50    34203
# >=50     10192
# 18-25      808
# <18          8
# Name: tranche_age, dtype: int64

# %%
df["tranche_age"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
df["balance"].hist()
# Out:
# <Axes: >

# %%
# quel est le solde moyen par tranche d'âge (groupeby .mean())
# faire des statistiques en fonction des catégorie de la variable qualitative
df.groupby("tranche_age")["balance"].mean()
# Out:
# tranche_age
# 18-25     916.949257
# 25-50    1236.063830
# <18        72.625000
# >=50     1822.763788
# Name: balance, dtype: float64

# %%
df
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
# Donner le code qui fait un filtre sur les clients de 
# plus de 25 ans et calcul l'age moyen en fonction du niveau d'éducation

# df["tranche_age"][(df["age"] > 25)] = "> 25"
# df.groupby("tranche_age")["age"].mean()
df[df["age"]>25].groupby("education")["age"].mean()
# Out:
# education
# primary      46.197571
# secondary    40.616153
# tertiary     39.883466
# unknown      45.830576
# Name: age, dtype: float64
